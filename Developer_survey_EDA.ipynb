# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df =pd.read_csv("survey_results_public.csv")
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
df.describe()
# Out:
#          Respondent           Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  64461.000000  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean   32554.079738     30.834111  3.190464e+242   1.037561e+05     40.782174
# std    18967.442360      9.585392            inf   2.268853e+05     17.816383
# min        1.000000      1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%    16116.000000     24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%    32231.000000     29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%    49142.000000     35.000000   1.250000e+05   9.500000e+04     44.000000
# max    65639.000000    279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %%
df.shape
# Out:
# (4213, 61)

# %%
df.describe()
# Out:
#          Respondent          Age     CompTotal  ConvertedComp  WorkWeekHrs
# count   4213.000000  4213.000000  4.213000e+03   4.213000e+03  4213.000000
# mean   27533.329694    32.072158  2.740265e+06   1.116038e+05    41.265523
# std    18439.176546     7.482935  4.297804e+07   2.459682e+05    15.344240
# min       10.000000    17.000000  0.000000e+00   0.000000e+00     2.000000
# 25%    12200.000000    26.000000  3.000000e+04   3.037200e+04    40.000000
# 50%    24863.000000    31.000000  7.200000e+04   6.050500e+04    40.000000
# 75%    46016.000000    36.000000  1.300000e+05   1.000000e+05    45.000000
# max    64938.000000    70.000000  1.900000e+09   2.000000e+06   425.000000

# %%
#df.isnull().sum().head(20)
#df= df.dropna()

# %%
#Do you code as a hobby?

Hobby =df["Hobbyist"].value_counts().head(10)

plt.figure(figsize=(10,6))
plt.title("Hobbyist")
sns.barplot(Hobby.index,Hobby.values)
plt.ylabel("Count of developers")
plt.xlabel("who are the Hobbyist")
# Out:
# C:\Users\HP PROBOOK 640\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 0, 'who are the Hobbyist')

# %%
df["Age"].describe()
# Out:
# count    4213.000000
# mean       32.072158
# std         7.482935
# min        17.000000
# 25%        26.000000
# 50%        31.000000
# 75%        36.000000
# max        70.000000
# Name: Age, dtype: float64

# %%
df["Age"].value_counts().head(20)
# Out:
# 28.0    272
# 30.0    263
# 25.0    255
# 29.0    252
# 26.0    248
# 27.0    247
# 31.0    216
# 24.0    208
# 32.0    205
# 35.0    184
# 33.0    178
# 34.0    174
# 23.0    157
# 36.0    127
# 37.0    125
# 38.0    118
# 39.0    115
# 22.0    114
# 40.0    107
# 42.0     77
# Name: Age, dtype: int64

# %%
plt.figure(figsize=(16,8))

sns.histplot(df["Age"],kde=True)

# %%
df["Age1stCode"].value_counts()
# Out:
# 12                      487
# 14                      456
# 15                      443
# 16                      406
# 13                      331
# 18                      329
# 10                      311
# 17                      256
# 11                      211
# 19                      178
# 8                       149
# 20                      115
# 9                       101
# 7                        81
# 21                       62
# 6                        50
# 22                       46
# 23                       39
# 25                       32
# 24                       27
# 5                        23
# Younger than 5 years     20
# 26                       18
# 28                       11
# 27                        9
# 32                        5
# 30                        4
# 31                        4
# 29                        3
# 39                        2
# 38                        1
# 33                        1
# 41                        1
# ...

# %%
plt.figure(figsize=(20,10))
sns.histplot(df["Age1stCode"],kde=True)

# %%
country =df["Country"].value_counts().head(25)
plt.figure(figsize=(20,10))
sns.barplot(x= country.index,y=country)

# %%
branch =df["MainBranch"].value_counts().head(5)
plt.figure(figsize=(27,10))
sns.barplot(x=branch.index,y=branch)

# %%
gender =df["Gender"].value_counts().head(4)
plt.figure(figsize=(20,20))

sns.barplot(x=gender.index,y=gender)

# %%
ethnic=df["Ethnicity"].value_counts().head(10)
plt.figure(figsize=(20,20))

sns.barplot(x=ethnic.index,y=ethnic)

# %%
edlevel =df["EdLevel"].value_counts().head(5)
plt.figure(figsize=(20,20))

sns.barplot(x=edlevel .index,y=edlevel)

# %%
employ =df["Employment"].value_counts()#.head(5)
plt.figure(figsize=(20,20))

sns.barplot(x=employ.index,y=employ)

# %%
UndergradMajor =df["UndergradMajor"].value_counts().head(5)
plt.figure(figsize=(40,20))

sns.barplot(x=UndergradMajor .index,y=UndergradMajor)

# %%
df["ConvertedComp"]#.describe()#value_counts()

sns.histplot(df["ConvertedComp"],kde=True)

# %%
database= df["DatabaseWorkedWith"].value_counts().head(10)

plt.figure(figsize=(20,20))

sns.barplot(x=database.index,y=database)

# %%
dev=df["DevType"].value_counts().head(5)

plt.figure(figsize=(40,20))

sns.barplot(x=dev.index,y=dev)

# %%
JobFactors=df["JobFactors"].value_counts().head(5)


plt.figure(figsize=(20,20))

sns.barplot(x=JobFactors.index,y=JobFactors)

# %%
lang =df["LanguageWorkedWith"].value_counts().head(5)


plt.figure(figsize=(30,20))

sns.barplot(x=lang.index,y=lang)

# %%
year =df["YearsCode"].value_counts()
plt.figure(figsize=(40,20))
sns.histplot(df["YearsCode"],kde=True)

# %%
year =df["YearsCodePro"].value_counts().head(5)
plt.figure(figsize=(40,20))
sns.histplot(df["YearsCodePro"],kde=True)

# %%
df["WorkWeekHrs"].value_counts()
plt.figure(figsize=(22,8))
sns.distplot(df["WorkWeekHrs"],kde=False)
